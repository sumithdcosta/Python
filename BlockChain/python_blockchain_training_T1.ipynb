# %% [markdown]
# <a href="https://colab.research.google.com/github/sumithdcosta/Python/blob/master/BlockChain/python_blockchain_training_T1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#blockchain : A distributed data storage consisying of containers (blocks) which
#             are connected
blockchain = []

def add_value():
  blockchain.append(5.3)
  print(blockchain)

add_value()
add_value()
add_value()
# Out:
# [5.3]
# [5.3, 5.3]
# [5.3, 5.3, 5.3]

# %%
#blockchain : A distributed data storage consisying of containers (blocks) which
#             are connected
blockchain = [[1]]

def add_value():
  #appending values to blockchian and retaining the last value
  blockchain.append([blockchain[-1],5.3])
  print(blockchain)

add_value()
add_value()
add_value()
# Out:
# [[1], [[1], 5.3]]
# [[1], [[1], 5.3], [[[1], 5.3], 5.3]]
# [[1], [[1], 5.3], [[[1], 5.3], 5.3], [[[[1], 5.3], 5.3], 5.3]]

# %%
#blockchain : A distributed data storage consisying of containers (blocks) which
#             are connected
blockchain = [[1]]

#adding kwargs to function
def add_value(transaction_amount):
  #appending values to blockchian and retaining the last value
  blockchain.append([blockchain[-1],transaction_amount])
  print(blockchain)

add_value(2)
add_value(0.9)
add_value(10.89)
# Out:
# [[1], [[1], 2]]
# [[1], [[1], 2], [[[1], 2], 0.9]]
# [[1], [[1], 2], [[[1], 2], 0.9], [[[[1], 2], 0.9], 10.89]]

# %%
#blockchain : A distributed data storage consisying of containers (blocks) which
#             are connected
#list with list.
blockchain = [[1]]

def get_last_blockchain_value():
  #function to return the value
  return blockchain[-1]

#adding kwargs to function
def add_value(transaction_amount):
  #appending values to blockchian and retaining the last value
  blockchain.append([get_last_blockchain_value(),transaction_amount])
  print(blockchain)


add_value(2)
add_value(0.9)
add_value(10.89)
# Out:
# [[1], [[1], 2]]
# [[1], [[1], 2], [[[1], 2], 0.9]]
# [[1], [[1], 2], [[[1], 2], 0.9], [[[[1], 2], 0.9], 10.89]]

# %%
#blockchain : A distributed data storage consisying of containers (blocks) which
#             are connected
#list with list.
blockchain = []

def get_last_blockchain_value():
  #function to return the value
  return blockchain[-1]

#adding kwargs to function and setting up default value
def add_value(transaction_amount,last_transaction=[1]):
  #appending values to blockchian and retaining the last value
  blockchain.append([last_transaction,transaction_amount])
  print(blockchain)

#using function with default argument
add_value(2)
add_value(0.9,get_last_blockchain_value())
add_value(10.89,get_last_blockchain_value())
# Out:
# [[[1], 2]]
# [[[1], 2], [[[1], 2], 0.9]]
# [[[1], 2], [[[1], 2], 0.9], [[[[1], 2], 0.9], 10.89]]

# %%
#using kward arguments:

#list with list.
blockchain = []

def get_last_blockchain_value():
  #function to return the value
  return blockchain[-1]

#adding kwargs to function and setting up default value
def add_value(transaction_amount, last_transaction=[1]):
  #appending values to blockchian and retaining the last value
  blockchain.append([last_transaction,transaction_amount])

#using function with default argument
add_value(2)
#using kwargs arguments
add_value(last_transaction=get_last_blockchain_value(), transaction_amount=0.9)
add_value(10.89,get_last_blockchain_value())

print(blockchain)
# Out:
# [[[1], 2], [[[1], 2], 0.9], [[[[1], 2], 0.9], 10.89]]

# %%
# user inputs:

#list with list.
blockchain = []

def get_last_blockchain_value():
  #function to return the value
  return blockchain[-1]

#adding kwargs to function and setting up default value
def add_value(transaction_amount, last_transaction=[1]):
  #appending values to blockchian and retaining the last value
  blockchain.append([last_transaction,transaction_amount])

#user input and converting to float
tx_amount = float(input('Your trasaction amount please: '))
#using function with default argument
add_value(tx_amount)

#using kwargs arguments
tx_amount = float(input('Your trasaction amount please: '))
add_value(last_transaction=get_last_blockchain_value(), transaction_amount=tx_amount)

tx_amount = float(input('Your trasaction amount please: '))
add_value(tx_amount,get_last_blockchain_value())

print(blockchain)
# Out:
# Your trasaction amount please: 5.99
# Your trasaction amount please: 6.99
# Your trasaction amount please: 7.99
# [[[1], 5.99], [[[1], 5.99], 6.99], [[[[1], 5.99], 6.99], 7.99]]

# %%
# reusability:

#list with list.
blockchain = []

def get_last_blockchain_value():
  #function to return the value
  return blockchain[-1]

#adding kwargs to function and setting up default value
def add_value(transaction_amount, last_transaction=[1]):
  #appending values to blockchian and retaining the last value
  blockchain.append([last_transaction,transaction_amount])

#using function for reusable code.
def get_user_input():
  return float(input('Your trasaction amount please: '))

#user input and converting to float
tx_amount = get_user_input()
#using function with default argument
add_value(tx_amount)

#using kwargs arguments
tx_amount = get_user_input()
add_value(last_transaction=get_last_blockchain_value(), transaction_amount=tx_amount)

tx_amount = get_user_input()
add_value(tx_amount,get_last_blockchain_value())

print(blockchain)
# Out:
# Your trasaction amount please: 6.99
# Your trasaction amount please: 7.99
# Your trasaction amount please: 8.99
# [[[1], 6.99], [[[1], 6.99], 7.99], [[[[1], 6.99], 7.99], 8.99]]

# %%
# comments and doc string:

#list with list.
#global variable
blockchain = []

def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_value(transaction_amount, last_transaction=[1]):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : transaction_amount :  The amopunt that should be added
    : last_transaction : The last blockchain transactio, default [1] 
  """
  #appending values to blockchian and retaining the last value
  blockchain.append([last_transaction,transaction_amount])

#using function for reusable code.
def get_user_input():
  """ Retruns the input of the user(a new transaction amount) as a float"""
  return float(input('Your trasaction amount please: ')) 
  
#user input and converting to float
tx_amount = get_user_input()
#using function with default argument
add_value(tx_amount)

#using kwargs arguments
tx_amount = get_user_input()
add_value(last_transaction=get_last_blockchain_value(), transaction_amount=tx_amount)

tx_amount = get_user_input()
add_value(tx_amount,get_last_blockchain_value())

print(blockchain)
# Out:
# Your trasaction amount please: 1
# Your trasaction amount please: 2
# Your trasaction amount please: 3
# [[[1], 1.0], [[[1], 1.0], 2.0], [[[[1], 1.0], 2.0], 3.0]]

# %%
# loops and conditionals:
#####################################################
#list
#global variable
blockchain = []

def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_value(transaction_amount, last_transaction=[1]):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : transaction_amount :  The amopunt that should be added
    : last_transaction : The last blockchain transactio, default [1] 
  """
  #appending values to blockchian and retaining the last value
  blockchain.append([last_transaction,transaction_amount])

#using function for reusable code.
def get_user_input():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  return float(input('Your trasaction amount please: ')) 
  
#user input and converting to float
tx_amount = get_user_input()
#using function with default argument
add_value(tx_amount)

while True:
  tx_amount = get_user_input()
  add_value(tx_amount,get_last_blockchain_value())

  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)

print('Done')

# %%
# conditionals:
#####################################################
#list
#global variable
blockchain = []

def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_value(transaction_amount, last_transaction=[1]):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : transaction_amount :  The amopunt that should be added
    : last_transaction : The last blockchain transactio, default [1] 
  """
  #appending values to blockchian and retaining the last value
  blockchain.append([last_transaction,transaction_amount])

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  return float(input('Your trasaction amount please: ')) 
  
def get_user_choice():
  user_input = input('Your Choice')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)



#user input and converting to float
tx_amount = get_user_input()
#using function with default argument
add_value(tx_amount)

while True:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Output the blockchain blocks')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_amount = get_transaction_value()
    add_value(tx_amount,get_last_blockchain_value())
  else:
    print_blockchain_elements()

print('Done')

# %%
# control conditional:
#####################################################
#list
#global variable
blockchain = []

def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(transaction_amount, last_transaction=[1]):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : transaction_amount :  The amopunt that should be added
    : last_transaction : The last blockchain transactio, default [1] 
  """
  #appending values to blockchian and retaining the last value
  if last_transaction == None :
    last_transaction = [1]
  blockchain.append([last_transaction,transaction_amount])

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  return float(input('Your trasaction amount please: ')) 
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)

while True:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Output the blockchain blocks')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_amount = get_transaction_value()
    add_transaction(tx_amount,get_last_blockchain_value())
  elif user_choice == '2':
    print_blockchain_elements()
  elif user_choice == 'q':
    break
  else:
    print('Input was invalid, please pick a value from the list!')    
  print('Choice registered !')
print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Your trasaction amount please: 2
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Your trasaction amount please: 3
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 2
# outputting block :  [[1], 2.0]
# outputting block :  [[[1], 2.0], 3.0]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : q
# Done

# %%
# booleans conditional:
#####################################################
#list
#global variable
blockchain = []

def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(transaction_amount, last_transaction=[1]):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : transaction_amount :  The amopunt that should be added
    : last_transaction : The last blockchain transactio, default [1] 
  """
  #appending values to blockchian and retaining the last value
  if last_transaction == None :
    last_transaction = [1]
  blockchain.append([last_transaction,transaction_amount])

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  return float(input('Your trasaction amount please: ')) 
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)

def verify_chain():
  block_index = 0
  is_valid = True
  for block in blockchain:
    if block_index == 0:
      block_index += 1
      continue
    elif block[0] == blockchain[block_index -1]:
      is_valid = True
    else :
      is_valid = False
      break
    block_index += 1
  return is_valid


while True:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Output the blockchain blocks')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_amount = get_transaction_value()
    add_transaction(tx_amount,get_last_blockchain_value())
  elif user_choice == '2':
    print_blockchain_elements()
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = [2]
  elif user_choice == 'q':
    break
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print('Invalid block chain!')
    break

  print('Choice registered !')
print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Your trasaction amount please: 10
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 2
# outputting block :  [[1], 10.0]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Your trasaction amount please: 5.5
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 2
# outputting block :  [[1], 10.0]
# outputting block :  [[[1], 10.0], 5.5]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : h
# Invalid block chain!
# Done

# %%
# for else and while else conditional:
#####################################################
#list
#global variable
blockchain = []

def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(transaction_amount, last_transaction=[1]):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : transaction_amount :  The amopunt that should be added
    : last_transaction : The last blockchain transactio, default [1] 
  """
  #appending values to blockchian and retaining the last value
  if last_transaction == None :
    last_transaction = [1]
  blockchain.append([last_transaction,transaction_amount])

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  return float(input('Your trasaction amount please: ')) 
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  block_index = 0
  is_valid = True
  for block in blockchain:
    if block_index == 0:
      block_index += 1
      continue
    elif block[0] == blockchain[block_index -1]:
      is_valid = True
    else :
      is_valid = False
      break
    block_index += 1
  return is_valid

waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Output the blockchain blocks')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_amount = get_transaction_value()
    add_transaction(tx_amount,get_last_blockchain_value())
  elif user_choice == '2':
    print_blockchain_elements()
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = [2]
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print('Invalid block chain!')
    break
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Your trasaction amount please: 2
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 2
# outputting block :  [[1], 2.0]
# --------------------
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : q
# Choice registered !
# User left
# Done

# %%
#  range:
#####################################################
#list
#global variable
blockchain = []

def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(transaction_amount, last_transaction=[1]):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : transaction_amount :  The amopunt that should be added
    : last_transaction : The last blockchain transactio, default [1] 
  """
  #appending values to blockchian and retaining the last value
  if last_transaction == None :
    last_transaction = [1]
  blockchain.append([last_transaction,transaction_amount])

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  return float(input('Your trasaction amount please: ')) 
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  is_valid = True
  for block_index in range(len(blockchain)):
    if block_index == 0:
      continue
    elif blockchain[block_index][0] == blockchain[block_index -1]:
      is_valid = True
    else :
      is_valid = False
      break
  return is_valid

waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Output the blockchain blocks')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_amount = get_transaction_value()
    add_transaction(tx_amount,get_last_blockchain_value())
  elif user_choice == '2':
    print_blockchain_elements()
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = [2]
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print('Invalid block chain!')
    break
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Your trasaction amount please: 34
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Your trasaction amount please: 232
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 2
# outputting block :  [[1], 34.0]
# outputting block :  [[[1], 34.0], 232.0]
# --------------------
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : h
# Invalid block chain!
# Done

# %%
# tuples :
#####################################################
#list
#global variable
blockchain = []
open_transactions = []
owner = 'Sumith' 

def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender, 'recipient': recipient, 'amount' : amount }
  open_transactions.append(transaction)

def mine_block():
  pass

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  is_valid = True
  for block_index in range(len(blockchain)):
    if block_index == 0:
      continue
    elif blockchain[block_index][0] == blockchain[block_index -1]:
      is_valid = True
    else :
      is_valid = False
      break
  return is_valid

waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Output the blockchain blocks')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    add_transaction(recipient, amount=amount)
    print(open_transactions)
  elif user_choice == '2':
    print_blockchain_elements()
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = [2]
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print('Invalid block chain!')
    break
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: M
# Your trasaction amount please: 3
# [{'sender': 'Sumith', 'recipient': 'M', 'amount': 3.0}]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: r
# Your trasaction amount please: 44
# [{'sender': 'Sumith', 'recipient': 'M', 'amount': 3.0}, {'sender': 'Sumith', 'recipient': 'r', 'amount': 44.0}]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Output the blockchain blocks
# q : Quit
# Your Choice : q
# Choice registered !
# User left
# Done

# %%
# dictionary in list :
#####################################################
#list
#global variable
genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[]
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender, 'recipient': recipient, 'amount' : amount }
  open_transactions.append(transaction)

def mine_block():
  last_block = blockchain[-1]
  hashed_block = ''
  for key in last_block:
    value = last_block[key]
    hashed_block = hashed_block + str(value)
  print(hashed_block)

  block = {
          'previous_hash': 'xyz', 
          'index' : len(blockchain), 
          'transactions' : open_transactions
  }
  blockchain.append(block)

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  is_valid = True
  for block_index in range(len(blockchain)):
    if block_index == 0:
      continue
    elif blockchain[block_index][0] == blockchain[block_index -1]:
      is_valid = True
    else :
      is_valid = False
      break
  return is_valid

waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    add_transaction(recipient, amount=amount)
    print(open_transactions)
  elif user_choice == '2':
    mine_block()
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = [2]
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  #if not verify_chain():
  #  print('Invalid block chain!')
  #  break
  print('Choice registered !')
else:
  print('User left')

print('Done')

# %%
# list comprehensions :
#####################################################
#list
#global variable
genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[]
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender, 'recipient': recipient, 'amount' : amount }
  open_transactions.append(transaction)

def hash_block(block):
  return '-'.join([str(block[key]) for key in block])

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block) 
  print(hashed_block)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : open_transactions
  }
  blockchain.append(block)

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
  return True
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    add_transaction(recipient, amount=amount)
    print(open_transactions)
  elif user_choice == '2':
    mine_block()
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# q : Quit
# Your Choice : 2
# -0-[]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# q : Quit
# Your Choice : 3
# outputting block :  {'previous_hash': '', 'index': 0, 'transactions': []}
# outputting block :  {'previous_hash': '-0-[]', 'index': 1, 'transactions': []}
# --------------------
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: eqwq
# Your trasaction amount please: 1211
# [{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# q : Quit
# Your Choice : 2
# -0-[]-1-[{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# q : Quit
# Your Choice : 2
# -0-[]-1-[{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]-2-[{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# q : Quit
# Your Choice : h
# outputting block :  {'previous_hash': '', 'index': 0, 'transactions': [{'sender': 'Chris', 'recipient': 'Max', 'amount': 100}]}
# outputting block :  {'previous_hash': '-0-[]', 'index': 1, 'transactions': [{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]}
# outputting block :  {'previous_hash': "-0-[]-1-[{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]", 'index': 2, 'transactions': [{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]}
# outputting block :  {'previous_hash': "-0-[]-1-[{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]-2-[{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]", 'index': 3, 'transactions': [{'sender': 'Sumith', 'recipient': 'eqwq', 'amount': 1211.0}]}
# --------------------
# Invalid block chain!
# Done

# %%
# sets :
#####################################################
#list
#global variable
genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[]
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'
participants = {owner}


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender,
                 'recipient': recipient, 
                 'amount' : amount }
  open_transactions.append(transaction)
  participants.add(sender)
  participants.add(recipient)

def hash_block(block):
  return '-'.join([str(block[key]) for key in block])

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block) 
  print(hashed_block)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : open_transactions
  }
  blockchain.append(block)

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
  return True
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('4: output participants')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    add_transaction(recipient, amount=amount)
    print(open_transactions)
  elif user_choice == '2':
    mine_block()
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == '4':
    print(participants)
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: wew
# Your trasaction amount please: 23
# [{'sender': 'Sumith', 'recipient': 'wew', 'amount': 23.0}]
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 4
# {'wew', 'Sumith'}
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : q
# Choice registered !
# User left
# Done

# %%
# adding mining logic :
#####################################################
#list
#global variable
MINING_REWARD = 10

genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[]
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'
participants = {owner}


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender,
                 'recipient': recipient, 
                 'amount' : amount }
  open_transactions.append(transaction)
  participants.add(sender)
  participants.add(recipient)

def hash_block(block):
  return '-'.join([str(block[key]) for key in block])

def get_balance(participant):
  tx_sender = [[tx['amount'] for tx in block['transactions'] if tx['sender'] == participant] for block in blockchain]
  amount_sent = 0
  for tx in tx_sender:
    if len(tx) > 0:
      amount_sent += tx[0]
  tx_recipient = [[tx['amount'] for tx in block['transactions'] if tx['recipient'] == participant] for block in blockchain]
  amount_received = 0
  for tx in tx_recipient:
    if len(tx) > 0:
      amount_received += tx[0]
  return  amount_received - amount_sent

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block) 
  reward_transaction = {
      'sender': 'MINING',
      'recipient': owner,
      'amount': MINING_REWARD

  }
  open_transactions.append(reward_transaction)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : open_transactions
  }
  blockchain.append(block)
  return True

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
  return True
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('4: output participants')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    add_transaction(recipient, amount=amount)
    print(open_transactions)
  elif user_choice == '2':
    if mine_block():
      open_transactions = []
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == '4':
    print(participants)
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('get balance : ', get_balance(owner))  
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 2
# get balance :  10
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 3
# outputting block :  {'previous_hash': '', 'index': 0, 'transactions': []}
# outputting block :  {'previous_hash': '-0-[]', 'index': 1, 'transactions': [{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}]}
# --------------------
# get balance :  10
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 2
# get balance :  20
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 3
# outputting block :  {'previous_hash': '', 'index': 0, 'transactions': []}
# outputting block :  {'previous_hash': '-0-[]', 'index': 1, 'transactions': [{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}]}
# outputting block :  {'previous_hash': "-0-[]-1-[{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}]", 'index': 2, 'transactions': [{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}]}
# --------------------
# get balance :  20
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : q
# get balance :  20
# Choice registered !
# User left
# Done

# %%
# validating transaction :
#####################################################
#list
#global variable
MINING_REWARD = 10

genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[]
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'
participants = {owner}


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

def verify_transaction(transaction):
  sender_balance = get_balance(transaction['sender'])
  return sender_balance >= transaction['amount']


#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender,
                 'recipient': recipient, 
                 'amount' : amount }
  if verify_transaction(transaction):
    open_transactions.append(transaction)
    participants.add(sender)
    participants.add(recipient)
    return True
  return False

def hash_block(block):
  return '-'.join([str(block[key]) for key in block])

def get_balance(participant):
  tx_sender = [[tx['amount'] for tx in block['transactions'] if tx['sender'] == participant] for block in blockchain]
  open_tx_sender = [tx['amount'] for tx in open_transactions if tx['sender'] == participant]
  tx_sender.append(open_tx_sender)
  amount_sent = 0
  for tx in tx_sender:
    if len(tx) > 0:
      amount_sent += tx[0]
  tx_recipient = [[tx['amount'] for tx in block['transactions'] if tx['recipient'] == participant] for block in blockchain]
  amount_received = 0
  for tx in tx_recipient:
    if len(tx) > 0:
      amount_received += tx[0]
  return  amount_received - amount_sent

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block) 
  reward_transaction = {
      'sender': 'MINING',
      'recipient': owner,
      'amount': MINING_REWARD

  }
  open_transactions.append(reward_transaction)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : open_transactions
  }
  blockchain.append(block)
  return True

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
  return True
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('4: output participants')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    if add_transaction(recipient, amount=amount):
      print('Added transaction')
    else:
      print('Tranaction failed')
    print(open_transactions)
  elif user_choice == '2':
    if mine_block():
      open_transactions = []
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == '4':
    print(participants)
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('get balance : ', get_balance(owner))  
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 2
# get balance :  10
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: sumith
# Your trasaction amount please: 20
# Tranaction failed
# []
# get balance :  10
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: wqq
# Your trasaction amount please: 212
# Tranaction failed
# []
# get balance :  10
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: sumith
# Your trasaction amount please: 4
# Added transaction
# [{'sender': 'Sumith', 'recipient': 'sumith', 'amount': 4.0}]
# get balance :  6.0
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# q : Quit
# Your Choice : q
# get balance :  6.0
# Choice registered !
# User left
# Done

# %%
# creating copies of transaction(reference and value copy) :
#####################################################
#list
#global variable
MINING_REWARD = 10

genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[]
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'
participants = {owner}


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

def verify_transaction(transaction):
  sender_balance = get_balance(transaction['sender'])
  return sender_balance >= transaction['amount']


#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender,
                 'recipient': recipient, 
                 'amount' : amount }
  if verify_transaction(transaction):
    open_transactions.append(transaction)
    participants.add(sender)
    participants.add(recipient)
    return True
  return False

def hash_block(block):
  return '-'.join([str(block[key]) for key in block])

def get_balance(participant):
  tx_sender = [[tx['amount'] for tx in block['transactions'] if tx['sender'] == participant] for block in blockchain]
  open_tx_sender = [tx['amount'] for tx in open_transactions if tx['sender'] == participant]
  tx_sender.append(open_tx_sender)
  amount_sent = 0
  for tx in tx_sender:
    if len(tx) > 0:
      amount_sent += tx[0]
  tx_recipient = [[tx['amount'] for tx in block['transactions'] if tx['recipient'] == participant] for block in blockchain]
  amount_received = 0
  for tx in tx_recipient:
    if len(tx) > 0:
      amount_received += tx[0]
  return  amount_received - amount_sent

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block) 
  reward_transaction = {
      'sender': 'MINING',
      'recipient': owner,
      'amount': MINING_REWARD

  }
  copied_transactions = open_transactions[:]
  copied_transactions.append(reward_transaction)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : copied_transactions
  }
  blockchain.append(block)
  return True

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
  return True

def verify_transactions():
  return all([verify_transaction(tx) for tx in open_transactions])
#  is_valid = True
#  for tx in open_transactions:
#    if verify_transaction(tx):
#      is_valid = True
#    else:
#      is_valid = False
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('4: output participants')
  print('5: check transaction validity')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    if add_transaction(recipient, amount=amount):
      print('Added transaction')
    else:
      print('Tranaction failed')
    print(open_transactions)
  elif user_choice == '2':
    if mine_block():
      open_transactions = []
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == '4':
    print(participants)
  elif user_choice == '5':
    if verify_transactions():
      print("All Transactions are valid")
    else:
      print('There are invalid transaction')
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('get balance : ', get_balance(owner))  
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: dasa
# Your trasaction amount please: 232
# Tranaction failed
# []
# get balance :  0
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 2
# get balance :  10
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 5
# All Transactions are valid
# get balance :  10
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 3
# outputting block :  {'previous_hash': '', 'index': 0, 'transactions': []}
# outputting block :  {'previous_hash': '-0-[]', 'index': 1, 'transactions': [{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}]}
# --------------------
# get balance :  10
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: ewew
# Your trasaction amount please: 5
# Added transaction
# [{'sender': 'Sumith', 'recipient': 'ewew', 'amount': 5.0}]
# get balance :  5.0
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 5
# All Transactions are valid
# get balance :  5.0
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 3
# outputting block :  {'previous_hash': '', 'index': 0, 'transactions': []}
# outputting block :  {'previous_hash': '-0-[]', 'index': 1, 'transactions': [{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}]}
# --------------------
# get balance :  5.0
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : q
# get balance :  5.0
# Choice registered !
# User left
# Done

# %%
# functions (using reduce function) and strings(for prinitng values with f format) :
#####################################################
import functools
#global variable
MINING_REWARD = 10

genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[]
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'
participants = {owner}


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

def verify_transaction(transaction):
  sender_balance = get_balance(transaction['sender'])
  return sender_balance >= transaction['amount']


#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender,
                 'recipient': recipient, 
                 'amount' : amount }
  if verify_transaction(transaction):
    open_transactions.append(transaction)
    participants.add(sender)
    participants.add(recipient)
    return True
  return False

def hash_block(block):
  return '-'.join([str(block[key]) for key in block])

def get_balance(participant):
  tx_sender = [[tx['amount'] for tx in block['transactions'] if tx['sender'] == participant] for block in blockchain]
  open_tx_sender = [tx['amount'] for tx in open_transactions if tx['sender'] == participant]
  tx_sender.append(open_tx_sender)
  amount_sent = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_sender,0)
  tx_recipient = [[tx['amount'] for tx in block['transactions'] if tx['recipient'] == participant] for block in blockchain]
  amount_received = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_recipient,0)
  return  amount_received - amount_sent

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block) 
  reward_transaction = {
      'sender': 'MINING',
      'recipient': owner,
      'amount': MINING_REWARD

  }
  copied_transactions = open_transactions[:]
  copied_transactions.append(reward_transaction)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : copied_transactions
  }
  blockchain.append(block)
  return True

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
  return True

def verify_transactions():
  return all([verify_transaction(tx) for tx in open_transactions])
#  is_valid = True
#  for tx in open_transactions:
#    if verify_transaction(tx):
#      is_valid = True
#    else:
#      is_valid = False
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('4: output participants')
  print('5: check transaction validity')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    if add_transaction(recipient, amount=amount):
      print('Added transaction')
    else:
      print('Tranaction failed')
    print(open_transactions)
  elif user_choice == '2':
    if mine_block():
      open_transactions = []
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == '4':
    print(participants)
  elif user_choice == '5':
    if verify_transactions():
      print("All Transactions are valid")
    else:
      print('There are invalid transaction')
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('Balance of {} : {:6.2f}'.format(owner, get_balance(owner)))  
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 2
# Balance of Sumith :  10.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: e
# Your trasaction amount please: 4
# Added transaction
# [{'sender': 'Sumith', 'recipient': 'e', 'amount': 4.0}]
# Balance of Sumith :   6.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: e
# Your trasaction amount please: 4
# Added transaction
# [{'sender': 'Sumith', 'recipient': 'e', 'amount': 4.0}, {'sender': 'Sumith', 'recipient': 'e', 'amount': 4.0}]
# Balance of Sumith :   2.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 2
# Balance of Sumith :  12.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction:
# Your trasaction amount please: 5
# Added transaction
# [{'sender': 'Sumith', 'recipient': '', 'amount': 5.0}]
# Balance of Sumith :   7.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : q
# Balance of Sumith :   7.00
# Choice registered !
# User left
# Done

# %%
# importing lib :
#####################################################
import functools
import hashlib
import json
#global variable
MINING_REWARD = 10

genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[]
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'
participants = {owner}


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

def verify_transaction(transaction):
  sender_balance = get_balance(transaction['sender'])
  return sender_balance >= transaction['amount']


#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender,
                 'recipient': recipient, 
                 'amount' : amount }
  if verify_transaction(transaction):
    open_transactions.append(transaction)
    participants.add(sender)
    participants.add(recipient)
    return True
  return False

def hash_block(block):
  return hashlib.sha256(json.dumps(block).encode()).hexdigest()
  
def get_balance(participant):
  tx_sender = [[tx['amount'] for tx in block['transactions'] if tx['sender'] == participant] for block in blockchain]
  open_tx_sender = [tx['amount'] for tx in open_transactions if tx['sender'] == participant]
  tx_sender.append(open_tx_sender)
  amount_sent = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_sender,0)
  tx_recipient = [[tx['amount'] for tx in block['transactions'] if tx['recipient'] == participant] for block in blockchain]
  amount_received = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_recipient,0)
  return  amount_received - amount_sent

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block)
  print(hashed_block) 
  reward_transaction = {
      'sender': 'MINING',
      'recipient': owner,
      'amount': MINING_REWARD

  }
  copied_transactions = open_transactions[:]
  copied_transactions.append(reward_transaction)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : copied_transactions
  }
  blockchain.append(block)
  return True

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
  return True

def verify_transactions():
  return all([verify_transaction(tx) for tx in open_transactions])
#  is_valid = True
#  for tx in open_transactions:
#    if verify_transaction(tx):
#      is_valid = True
#    else:
#      is_valid = False
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('4: output participants')
  print('5: check transaction validity')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    if add_transaction(recipient, amount=amount):
      print('Added transaction')
    else:
      print('Tranaction failed')
    print(open_transactions)
  elif user_choice == '2':
    if mine_block():
      open_transactions = []
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == '4':
    print(participants)
  elif user_choice == '5':
    if verify_transactions():
      print("All Transactions are valid")
    else:
      print('There are invalid transaction')
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('Balance of {} : {:6.2f}'.format(owner, get_balance(owner)))  
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 2
# fdcd010164e24fe2247e9c6b20e211ab96c0cb7b3ad2da9f3e5feaac47ecc4d1
# Balance of Sumith :  10.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 2
# 82d4dd4c377d3d9389f5defa4e1b83c6dec89a29a90d0ebcf7269576a345a330
# Balance of Sumith :  20.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 3
# outputting block :  {'previous_hash': '', 'index': 0, 'transactions': []}
# outputting block :  {'previous_hash': 'fdcd010164e24fe2247e9c6b20e211ab96c0cb7b3ad2da9f3e5feaac47ecc4d1', 'index': 1, 'transactions': [{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}]}
# outputting block :  {'previous_hash': '82d4dd4c377d3d9389f5defa4e1b83c6dec89a29a90d0ebcf7269576a345a330', 'index': 2, 'transactions': [{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}]}
# --------------------
# Balance of Sumith :  20.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : q
# Balance of Sumith :  20.00
# Choice registered !
# User left
# Done

# %%
# proof of work :
#####################################################
import functools
import hashlib as hl
import json
#global variable
MINING_REWARD = 10

genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[],
          'proof':100
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'
participants = {owner}


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

def verify_transaction(transaction):
  sender_balance = get_balance(transaction['sender'])
  return sender_balance >= transaction['amount']


#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  transaction = {'sender': sender,
                 'recipient': recipient, 
                 'amount' : amount }
  if verify_transaction(transaction):
    open_transactions.append(transaction)
    participants.add(sender)
    participants.add(recipient)
    return True
  return False

def hash_block(block):
  return hl.sha256(json.dumps(block).encode()).hexdigest()

def valid_proof(transactions, last_hash, proof):
  guess = (str(transactions) + str(last_hash) + str(proof)).encode()
  guess_hash = hl.sha256(guess).hexdigest()
  print(guess_hash)
  return guess_hash[0:2] == '00'

def proof_of_work():
  last_block = blockchain[-1]
  last_hash = hash_block(last_block)
  proof = 0
  while not valid_proof(open_transactions, last_hash, proof):
    proof += 1
  return proof
  

def get_balance(participant):
  tx_sender = [[tx['amount'] for tx in block['transactions'] if tx['sender'] == participant] for block in blockchain]
  open_tx_sender = [tx['amount'] for tx in open_transactions if tx['sender'] == participant]
  tx_sender.append(open_tx_sender)
  amount_sent = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_sender,0)
  tx_recipient = [[tx['amount'] for tx in block['transactions'] if tx['recipient'] == participant] for block in blockchain]
  amount_received = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_recipient,0)
  return  amount_received - amount_sent

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block)
  proof = proof_of_work() 
  reward_transaction = {
      'sender': 'MINING',
      'recipient': owner,
      'amount': MINING_REWARD

  }
  copied_transactions = open_transactions[:]
  copied_transactions.append(reward_transaction)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : copied_transactions,
           'proof': proof
  }
  blockchain.append(block)
  return True

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
    if not valid_proof(block['transactions'][:-1], block['previous_hash'], block['proof']):
      print('Prood of work invalid')
      return False
  return True

def verify_transactions():
  return all([verify_transaction(tx) for tx in open_transactions])
#  is_valid = True
#  for tx in open_transactions:
#    if verify_transaction(tx):
#      is_valid = True
#    else:
#      is_valid = False
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('4: output participants')
  print('5: check transaction validity')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    if add_transaction(recipient, amount=amount):
      print('Added transaction')
    else:
      print('Tranaction failed')
    print(open_transactions)
  elif user_choice == '2':
    if mine_block():
      open_transactions = []
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == '4':
    print(participants)
  elif user_choice == '5':
    if verify_transactions():
      print("All Transactions are valid")
    else:
      print('There are invalid transaction')
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('Balance of {} : {:6.2f}'.format(owner, get_balance(owner)))  
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 2
# 838df95b3f7ed54635ad873f1859ffa586d66b136051e5e66cb330d99b66e1f0
# a88fb2475ea9b041de517b54675992441ec5c8e95d2f1d5d1dcfdad4bff283e0
# 277aa459bd17d0f303f5dbdf6eb95eb0dd80083a5c070f48a04df7d446400176
# 8eee6a4fb377250eefc9f05d4fa57c2a6571f41346569928a3f901156738f57c
# 6b4f6947c998d3fb0ace8c3078dcde25f1ee6a3b9e1817bdd65166788fdaaef3
# 0f401cba4a3a0d39fa3d6559ced9bca5bfc80e99e7c8f26b9e580ecc4dfd38d1
# 8e37530340727b1f2bf099d17e2d9e9afaa47d675d7e315907ea9462ebde64f4
# 65c028b444aa4ab754b7e3116026f3ae69c415b91f417717cf548cc255c6b8dd
# 1db56395f0e7a3946653862d0181931c6f330563a18ea502a83f4442bfa80801
# 7c76829c070c33eaeaaa0ee8a81af9afb664862f1f6b59ff8b9e1b495bd504f2
# 677b640b81e44944f8b6bae67b8c0bc5695d3a8e8bdfd93c18229a42c78496a4
# 18c9174818a7eb244add1d0e8564cf98640574015435a400e3a57092a4ec5be6
# beedd2cbda5349639dd09ac2d1a2e4366bd9ffd4aeb32dd9cb92c8ad1f56756f
# 501f9d6b38d168991b68ebe2e3f766b63c166bbfa6bca487ec1e6a1bb6f3f6c0
# 71239195e57e5c2899650806bb307674d533e2a71f8cc8010cb7e48ab573ea7e
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# Balance of Sumith :  10.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 1
# Enter the recipent of the transaction: we
# Your trasaction amount please: 5
# Added transaction
# [{'sender': 'Sumith', 'recipient': 'we', 'amount': 5.0}]
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# Balance of Sumith :   5.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 3
# outputting block :  {'previous_hash': '', 'index': 0, 'transactions': [], 'proof': 100}
# outputting block :  {'previous_hash': 'cd4a687519f17cff11d3adfe995a88794eaee22ec4e8aca7765863e6e49c9dae', 'index': 1, 'transactions': [{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}], 'proof': 121}
# --------------------
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# Balance of Sumith :   5.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 4
# {'Sumith', 'we'}
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# Balance of Sumith :   5.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 56aa5ba35d3dbdf8e7efd118e9e5ef89eae72d1e3c63a0c7a0552958b7f5aba8
# f86009c78f573f21181472461e338d8edc65a3d9ff6241bf9f0180b6a7313385
# e30fba20e88786cfce8ddc959fa754bfeaf5185a41942c13b46654cab844d509
# 8f72fd771f07cc07c07b619beb187d93da82368b67b6492fa96dadf371db6d1b
# 7afe0aa6277ed203231ce4b0cf3fb85a57304eaa6983b888e09fbd4716dba907
# 876d14ce589e627d7a5a0a41554827c4515ee370481794f1166c4db345895add
# 4b9940928775db3bb7f2ed6356947c76d5c5b43b6de827c6e16971ebe7839c45
# 005e65f8f5f5079eb883828e69e5ce3756441323ae0d78016e33dde86f88ab4d
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# 005e65f8f5f5079eb883828e69e5ce3756441323ae0d78016e33dde86f88ab4d
# Balance of Sumith :  15.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 3
# outputting block :  {'previous_hash': '', 'index': 0, 'transactions': [], 'proof': 100}
# outputting block :  {'previous_hash': 'cd4a687519f17cff11d3adfe995a88794eaee22ec4e8aca7765863e6e49c9dae', 'index': 1, 'transactions': [{'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}], 'proof': 121}
# outputting block :  {'previous_hash': '8905d526c53720fd64e550d3d787d95e900f05273099999a027c176d2e220fe1', 'index': 2, 'transactions': [{'sender': 'Sumith', 'recipient': 'we', 'amount': 5.0}, {'sender': 'MINING', 'recipient': 'Sumith', 'amount': 10}], 'proof': 111}
# --------------------
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# 005e65f8f5f5079eb883828e69e5ce3756441323ae0d78016e33dde86f88ab4d
# Balance of Sumith :  15.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 4
# {'Sumith', 'we'}
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# 005e65f8f5f5079eb883828e69e5ce3756441323ae0d78016e33dde86f88ab4d
# Balance of Sumith :  15.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 5
# All Transactions are valid
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# 005e65f8f5f5079eb883828e69e5ce3756441323ae0d78016e33dde86f88ab4d
# Balance of Sumith :  15.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : q
# 00927daff801283b4fbd2fbbc289cd149e306b3bd69e12a6bf500cd77a76ce04
# 005e65f8f5f5079eb883828e69e5ce3756441323ae0d78016e33dde86f88ab4d
# Balance of Sumith :  15.00
# Choice registered !
# User left
# Done

# %%
# fixing a hash order fault : OrderDict
#####################################################
import functools
import hashlib as hl
import json
from collections import OrderedDict
#global variable
MINING_REWARD = 10

genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[],
          'proof':100
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'
participants = {owner}


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

def verify_transaction(transaction):
  sender_balance = get_balance(transaction['sender'])
  return sender_balance >= transaction['amount']


#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  #transaction = {'sender': sender,
  #               'recipient': recipient, 
  #               'amount' : amount }
  transaction = OrderedDict([('sender', sender),
                            ('recipient', recipient), 
                            ('amount' , amount)])
  if verify_transaction(transaction):
    open_transactions.append(transaction)
    participants.add(sender)
    participants.add(recipient)
    return True
  return False

def hash_block(block):
  return hl.sha256(json.dumps(block, sort_keys=True).encode()).hexdigest()

def valid_proof(transactions, last_hash, proof):
  guess = (str(transactions) + str(last_hash) + str(proof)).encode()
  guess_hash = hl.sha256(guess).hexdigest()
  print(guess_hash)
  return guess_hash[0:2] == '00'

def proof_of_work():
  last_block = blockchain[-1]
  last_hash = hash_block(last_block)
  proof = 0
  while not valid_proof(open_transactions, last_hash, proof):
    proof += 1
  return proof
  

def get_balance(participant):
  tx_sender = [[tx['amount'] for tx in block['transactions'] if tx['sender'] == participant] for block in blockchain]
  open_tx_sender = [tx['amount'] for tx in open_transactions if tx['sender'] == participant]
  tx_sender.append(open_tx_sender)
  amount_sent = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_sender,0)
  tx_recipient = [[tx['amount'] for tx in block['transactions'] if tx['recipient'] == participant] for block in blockchain]
  amount_received = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_recipient,0)
  return  amount_received - amount_sent

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block)
  proof = proof_of_work() 
  #reward_transaction = {
  #    'sender': 'MINING',
  #    'recipient': owner,
  #    'amount': MINING_REWARD
  #}
  reward_transaction = OrderedDict(
                      [('sender', 'MINING'),
                      ('recipient', owner),
                      ('amount', MINING_REWARD)])
  copied_transactions = open_transactions[:]
  copied_transactions.append(reward_transaction)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : copied_transactions,
           'proof': proof
  }
  blockchain.append(block)
  return True

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
    if not valid_proof(block['transactions'][:-1], block['previous_hash'], block['proof']):
      print('Prood of work invalid')
      return False
  return True

def verify_transactions():
  return all([verify_transaction(tx) for tx in open_transactions])
#  is_valid = True
#  for tx in open_transactions:
#    if verify_transaction(tx):
#      is_valid = True
#    else:
#      is_valid = False
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('4: output participants')
  print('5: check transaction validity')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    if add_transaction(recipient, amount=amount):
      print('Added transaction')
    else:
      print('Tranaction failed')
    print(open_transactions)
  elif user_choice == '2':
    if mine_block():
      open_transactions = []
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == '4':
    print(participants)
  elif user_choice == '5':
    if verify_transactions():
      print("All Transactions are valid")
    else:
      print('There are invalid transaction')
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('Balance of {} : {:6.2f}'.format(owner, get_balance(owner)))  
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 2
# Your Choice : 1
# 192a620abb0343decb9a29d7d9b911c9450ba4e48cc7fa5256e99155371aedb6
# 4b5b8289ba0eb454a3a51da1f4f6b2cacb0c41725b8a00031e360a495e8f280a
# 7d67a07fa8f75a27133c8edd485505db4b374e06a937da73db79aa2e781e4486
# 4569979386e12581b05dead3abe3d6711ecb933f42c5c635f12e8b33b0dce1bc
# e443beb3262f36bb1aaf9afdbacb440941a047b27493e2a30d00a0288db44ab8
# 3abe3eb5bb76363abd3841a30a44aece6b461c78add963166416e613ea9b3170
# ed26a2c7414b523b520cc2743574653521dc5865527ef7d0b3b6dd1e3ccd71cb
# ba9b4a0ede4ac209ff884a5ebc531e410aa74db9dc07a8bbd74b8366592f41b9
# 1f33e574fc42d5fb9d3a560f192575ab2b2fdc12edced74ac5a903f758fbed0b
# c270ba491290bff200844b6bd1e6aa2a181328d31f23376b33b539faa8fcde63
# c9bb4601fd0a3fbfde046472733786fd5bc7ceebc009d72036a5525e9d8d51e2
# 5bf9547091a78e65d225ef1c237888c8d8d82252235972f0eb3b9fc3c7b8fb77
# 1c0c50644265b6edb08f5f67bcf0f4f39d93c6b05fe74f11004638cf4b899d44
# be63ce9ac6eb88e34cf42d84a14e7ae702a8a86e95c82204930671bac80a4419
# d5a80b8c64ce264036027f8abf526f5b3f95a457cc4b8e6f36ebcb01f0679303
# c556a75589c99a912229bbd936daef9b7fbcf084cfe165c9d3a78277501d0fa1
# ead27783e919924624cfe191aa67e207b48a8ba340abf7a2efaf54514009fe70
# dcbd54d5504abb0b6fc35e5c537cd5f92b7644c2335a2d8a5e58497c98b8d806
# 002e3fad6220d48dc66978cf15269a9d5fc42483b058df20e0900d7c99a99129
# 0009d7fd8e3af23b4d72105473696ee9a5956930361a3819d39c7f022064828d
# 002e3fad6220d48dc66978cf15269a9d5fc42483b058df20e0900d7c99a99129
# Balance of Sumith :  16.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 5
# All Transactions are valid
# 0009d7fd8e3af23b4d72105473696ee9a5956930361a3819d39c7f022064828d
# 002e3fad6220d48dc66978cf15269a9d5fc42483b058df20e0900d7c99a99129
# Balance of Sumith :  16.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : q
# 0009d7fd8e3af23b4d72105473696ee9a5956930361a3819d39c7f022064828d
# 002e3fad6220d48dc66978cf15269a9d5fc42483b058df20e0900d7c99a99129
# Balance of Sumith :  16.00
# Choice registered !
# User left
# Done

# %%
pwd
# Out:
# '/content'

# %%
# !ls -lrt
# Out:
# total 8
# drwxr-xr-x 1 root root 4096 Mar  3 18:11 sample_data
# -rw-r--r-- 1 root root   32 Mar  9 10:27 execution_methods.py

# %%
# %%writefile hash_util.py
import hashlib as hl
import json

def hash_string_256(string):
  return hl.sha256(string).hexdigest()

def hash_block(block):
  return hash_string_256(json.dumps(block, sort_keys=True).encode())
# Out:
# Writing hash_util.py

# %%
# %%writefile blockchain.py
# fixing a hash order fault : OrderDict
#####################################################
import functools
import hashlib as hl
import json
from collections import OrderedDict

from hash_util import hash_string_256, hash_block

#global variable
MINING_REWARD = 10

genesis_block = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[],
          'proof':100
  }
blockchain = [genesis_block]
open_transactions = []
owner = 'Sumith'
participants = {owner}


def get_last_blockchain_value():
  """ returns the last value of the current bloackchain """
  #function to return the value
  if len(blockchain) < 1 :
    return None
  return blockchain[-1]

def verify_transaction(transaction):
  sender_balance = get_balance(transaction['sender'])
  return sender_balance >= transaction['amount']


#adding kwargs to function and setting up default value
#transaction_amount is local varible
def add_transaction(recipient,sender=owner, amount=1.0):
  """ Appends a new value as well as the last blockchain value to teh block

  Arguments:
    : Sender :  sender of coins
    : recipent : recipient of coin
  """
  #appending values to blockchian and retaining the last value
  #transaction = {'sender': sender,
  #               'recipient': recipient, 
  #               'amount' : amount }
  transaction = OrderedDict([('sender', sender),
                            ('recipient', recipient), 
                            ('amount' , amount)])
  if verify_transaction(transaction):
    open_transactions.append(transaction)
    participants.add(sender)
    participants.add(recipient)
    return True
  return False


def valid_proof(transactions, last_hash, proof):
  guess = (str(transactions) + str(last_hash) + str(proof)).encode()
  guess_hash = hash_string_256(guess)
  print(guess_hash)
  return guess_hash[0:2] == '00'

def proof_of_work():
  last_block = blockchain[-1]
  last_hash = hash_block(last_block)
  proof = 0
  while not valid_proof(open_transactions, last_hash, proof):
    proof += 1
  return proof
  

def get_balance(participant):
  tx_sender = [[tx['amount'] for tx in block['transactions'] if tx['sender'] == participant] for block in blockchain]
  open_tx_sender = [tx['amount'] for tx in open_transactions if tx['sender'] == participant]
  tx_sender.append(open_tx_sender)
  amount_sent = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_sender,0)
  tx_recipient = [[tx['amount'] for tx in block['transactions'] if tx['recipient'] == participant] for block in blockchain]
  amount_received = functools.reduce(lambda tx_sum, tx_amt: tx_sum + sum(tx_amt) if len(tx_amt) > 0 else tx_sum + 0, tx_recipient,0)
  return  amount_received - amount_sent

def mine_block():
  last_block = blockchain[-1]
  #list comprehensions
  hashed_block = hash_block(last_block)
  proof = proof_of_work() 
  #reward_transaction = {
  #    'sender': 'MINING',
  #    'recipient': owner,
  #    'amount': MINING_REWARD
  #}
  reward_transaction = OrderedDict(
                      [('sender', 'MINING'),
                      ('recipient', owner),
                      ('amount', MINING_REWARD)])
  copied_transactions = open_transactions[:]
  copied_transactions.append(reward_transaction)
  block = {
          'previous_hash': hashed_block, 
          'index' : len(blockchain), 
          'transactions' : copied_transactions,
           'proof': proof
  }
  blockchain.append(block)
  return True

#using function for reusable code.
def get_transaction_value():
  """ Retruns the input of the user(a new transaction amount) as a float
  """
  tx_recipient = input('Enter the recipent of the transaction: ') 
  tx_amount = float(input('Your trasaction amount please: ')) 
  return (tx_recipient, tx_amount)
  
def get_user_choice():
  user_input = input('Your Choice : ')
  return user_input

def print_blockchain_elements():
  #use for loop to output the blockchain list console
  for block in blockchain:
    print('outputting block : ', block)
  else:
    print('-' * 20)

def verify_chain():
  """verify current blockchain"""
  for (index, block) in enumerate(blockchain):
    if index == 0:
      continue
    if block['previous_hash'] != hash_block(blockchain[index -1]):
      return False
    if not valid_proof(block['transactions'][:-1], block['previous_hash'], block['proof']):
      print('Prood of work invalid')
      return False
  return True

def verify_transactions():
  return all([verify_transaction(tx) for tx in open_transactions])
#  is_valid = True
#  for tx in open_transactions:
#    if verify_transaction(tx):
#      is_valid = True
#    else:
#      is_valid = False
  
waiting_for_input = True

while waiting_for_input:
  print('Please choose')
  print('1: Add a new transaction value')
  print('2: Mine a new block')
  print('3: Output the blockchain blocks')
  print('4: output participants')
  print('5: check transaction validity')
  print('q : Quit ')
  user_choice = get_user_choice()
  if user_choice == '1':
    tx_data = get_transaction_value()
    recipient, amount = tx_data
    if add_transaction(recipient, amount=amount):
      print('Added transaction')
    else:
      print('Tranaction failed')
    print(open_transactions)
  elif user_choice == '2':
    if mine_block():
      open_transactions = []
  elif user_choice == '3':
    print_blockchain_elements()
  elif user_choice == '4':
    print(participants)
  elif user_choice == '5':
    if verify_transactions():
      print("All Transactions are valid")
    else:
      print('There are invalid transaction')
  elif user_choice == 'h':
    if len(blockchain) >=1:
      blockchain[0] = {
          'previous_hash': '', 
          'index':0 , 
          'transactions':[{'sender':'Chris', 'recipient': 'Max', 'amount': 100}]
      }
  elif user_choice == 'q':
    waiting_for_input = False
  else:
    print('Input was invalid, please pick a value from the list!')    
  
  if not verify_chain():
    print_blockchain_elements()
    print('Invalid block chain!')
    break
  print('Balance of {} : {:6.2f}'.format(owner, get_balance(owner)))  
  print('Choice registered !')
else:
  print('User left')

print('Done')
# Out:
# Overwriting blockchain.py

# %%
# !python blockchain.py
# Out:
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : 2
# 192a620abb0343decb9a29d7d9b911c9450ba4e48cc7fa5256e99155371aedb6
# 4b5b8289ba0eb454a3a51da1f4f6b2cacb0c41725b8a00031e360a495e8f280a
# 7d67a07fa8f75a27133c8edd485505db4b374e06a937da73db79aa2e781e4486
# 4569979386e12581b05dead3abe3d6711ecb933f42c5c635f12e8b33b0dce1bc
# e443beb3262f36bb1aaf9afdbacb440941a047b27493e2a30d00a0288db44ab8
# 3abe3eb5bb76363abd3841a30a44aece6b461c78add963166416e613ea9b3170
# ed26a2c7414b523b520cc2743574653521dc5865527ef7d0b3b6dd1e3ccd71cb
# ba9b4a0ede4ac209ff884a5ebc531e410aa74db9dc07a8bbd74b8366592f41b9
# 1f33e574fc42d5fb9d3a560f192575ab2b2fdc12edced74ac5a903f758fbed0b
# c270ba491290bff200844b6bd1e6aa2a181328d31f23376b33b539faa8fcde63
# c9bb4601fd0a3fbfde046472733786fd5bc7ceebc009d72036a5525e9d8d51e2
# 7d2deacb6128bc37e5e407de2c0c196f31d49b52d790487d28a4b29e64c246ce
# 298fa55df66381b1b62d600be633690b2e5fac940fec6d5aa3150204f914f8d8
# 42bd0582ca607f48be463060d6e0f0ed51712c5ba49ffd60e486c891156f157f
# f10c782c0591bfe76b182444a07bb49d75a1e4b498d3048902630bd56ee0f15f
# 8b6ff90ddf2ecadc39e7c60b6bbac6b973ab00a0810e1ef9a8a86d10055f2edb
# af1d44695dc1afb040aab31120b0d0d09d6ed1a61932610cd663a139622be0e8
# 6e04d0ee050fc4c31fb6247e8962161b2cbfeb288e2e39adeb82ab5c0407360b
# ae12fbca084a7d2dbd572d1287b6d78308e414922feca52062fe115657700e39
# bce7f1311d688d4725dbd38598983cb869440e0d5ae57d1131742ed7b5416bde
# bf19453bcf8caad6c681c9e62071a8868058d0e86839551a96c0dbf2f8231114
# 779f98f65b2748af6156d8cee7217d080f77296e6a07ebfa525145fcca07802a
# 3f4a09a7cdc79ba78b2c33e097602f59f1a794f67245ff7012d2b217c064fd8f
# 52e211bf47ce887efe5d9c8646d180b7fadaa4a031ef3ee02b16e59fe8e07236
# 814a06dc4c2ce7295672021a3cde39b80a0cdeae78ad1a53184a919ae1012e28
# 28d241717847dc72ba328ae9b3ea92838797d1fb3ef06a9343678b2b7b928b4d
# a68125116da1adb2fcf86137c4357d114daef4a75994af74facbe26e33dd3d30
# af1d5d807ee383b257fb44049245ba9304caabc6b38fbb701c01574da5ca0388
# 08efbdf405c92ae64e831893173fbc307d219dff14d1004eeca83228901eef76
# 6f0441eb129577c53e25f85d76277e62f2906791b516347199d164125a844867
# 37dd64e1d423ea68f7399f8124cef6855543883526d1de049db748f5ecf78bac
# 2c3cd360f7a548a306557c140379b973014d0d5526de9092b1b156b55fc12679
# 75d1ec13ece4227688d3ce4665cd107a2353c4b95b473c12800abac0bbda539f
# 6cdd730277b131346a3ab4167cde75a8066496a3d2465be89e6e79b8c2248d40
# 2c9381bd00384a6ac6cbd35dadd915443d999e44b0cbe96ca83eb6f72f070814
# e76839e6cdf387a8cc53a0e706debcc716e8d4d454f7be8a7b19fe795909a6f3
# b2af51c8f5584568bf5c4f25aca8eb2d6693d3df96bf3bd58d2df06eb2b2f64b
# 022ecef3dc4753f0061650ae7e2247270cb8550a55296e05ea8c422197149db0
# 4793caf0f27a2b95807d58b853827b82921f71c720b3a4c47e362c5bc556b6d9
# ddca8f16b71477069ea1f85654975a3b4b52c7e5e503dbe59e5fd2966080ddb7
# cde5b55c1b4b840e267e7c01cd1f0ef20514030ea3fc3450a9bc2a9b9ecc887c
# eff45a987bb2b2eb76ceb235a98b9dfd4b4a334393557b4cbbb0c18f426bb0a8
# 8f7547752daac469d8bfd67f5001ce6853231e08fd8d74d6ba7820c6fc8f2c81
# 7770176e89ead54c42bffdad835e43089b4f2a3bc45e4db2276f2e49b5554717
# c750bf7d843f75e585e77d67fca3d2a6ad73756fb9fa629c5b6466ebd199957d
# a3986cd251b413426bbd7bfa8124a6fed2dd000e3efe2a7e57647bf04b5f768e
# 43b911257eb0cfbafcaa54bc49cfe69d9f14f7e8311c7b110f3dc858157ecfb7
# 273abbb497681ab5da95ae887b036694a6165ca8cecf71946fd4d11747eea065
# 57ab0de97d80c3387d07e03b6f378b4912b4db4c0d5078585745754dbe41d163
# 0009d7fd8e3af23b4d72105473696ee9a5956930361a3819d39c7f022064828d
# 0009d7fd8e3af23b4d72105473696ee9a5956930361a3819d39c7f022064828d
# Balance of Sumith :  10.00
# Choice registered !
# Please choose
# 1: Add a new transaction value
# 2: Mine a new block
# 3: Output the blockchain blocks
# 4: output participants
# 5: check transaction validity
# q : Quit
# Your Choice : q
# 0009d7fd8e3af23b4d72105473696ee9a5956930361a3819d39c7f022064828d
# Balance of Sumith :  10.00
# Choice registered !
# User left
# Done

# %%
# !ls -lrt
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Mar  3 18:11 sample_data
# -rw-r--r-- 1 root root   32 Mar  9 10:27 execution_methods.py
# -rw-r--r-- 1 root root  196 Mar  9 10:31 transaction.py
# -rw-r--r-- 1 root root 6179 Mar  9 10:32 blockchain.py
